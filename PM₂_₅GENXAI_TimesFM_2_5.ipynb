# %%
# Partha Pratim Ray, Sikkim University, Sikkim, India ppray@cus.ac.in, parthapratimray1986@gmail.com
# May, 2026

# %%
# ============================================================
# CELL 1: Install Required Libraries for Colab
# ============================================================
# This installs:
# 1. Latest Hugging Face Transformers from GitHub
# 2. Standard scientific and forecasting libraries
#
# IMPORTANT:
# After this cell finishes, restart the Colab runtime once:
# Runtime -> Restart runtime
# Then continue from Cell 2.
#
# TimesFM 2.5 support may require the latest Transformers source.
# ============================================================

# !pip install -q --upgrade pip

# Latest Transformers source for TimesFM 2.5 support.
# !pip install -q "git+https://github.com/huggingface/transformers.git"

# Standard scientific libraries.
# !pip install -q accelerate safetensors sentencepiece einops
# !pip install -q statsmodels scipy scikit-learn pandas numpy matplotlib

print("Installation completed.")
print("Please restart runtime once before running Cell 2.")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 43.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
# Installation completed.
# Please restart runtime once before running Cell 2.

# %%
# ============================================================
# CELL 2: Import Libraries
# ============================================================

import warnings
warnings.filterwarnings("ignore")

import os
import math
import gc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from google.colab import files

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

import torch

np.random.seed(42)

print("Libraries imported successfully.")
print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
# Out:
# Libraries imported successfully.
# Torch version: 2.10.0+cu128
# CUDA available: True

# %%
# ============================================================
# CELL 3A: User Upload Dataset and Validate Required Columns
# ============================================================
# The user should upload a CSV file containing the following columns:
#
# date, pm10, pm2_5, carbon_monoxide, nitrogen_dioxide,
# sulphur_dioxide, ozone, aerosol_optical_depth, dust, uv_index
#
# Expected date format:
# DD-MM-YYYY
# Example:
# 04-08-2022
# ============================================================

from google.colab import files

print("Please upload your PM₂.₅ dataset CSV file.")
print("Required columns:")
print([
    "date",
    "pm10",
    "pm2_5",
    "carbon_monoxide",
    "nitrogen_dioxide",
    "sulphur_dioxide",
    "ozone",
    "aerosol_optical_depth",
    "dust",
    "uv_index"
])

uploaded = files.upload()

if len(uploaded) == 0:
    raise ValueError("No file was uploaded. Please upload a CSV dataset.")

file_name = list(uploaded.keys())[0]

if not file_name.lower().endswith(".csv"):
    raise ValueError("Please upload a CSV file only.")

df = pd.read_csv(file_name)

# Standardize column names
df.columns = df.columns.str.strip().str.lower()

required_cols = [
    "date",
    "pm10",
    "pm2_5",
    "carbon_monoxide",
    "nitrogen_dioxide",
    "sulphur_dioxide",
    "ozone",
    "aerosol_optical_depth",
    "dust",
    "uv_index"
]

missing_cols = [col for col in required_cols if col not in df.columns]

if missing_cols:
    raise ValueError(
        f"The uploaded dataset is missing the following required columns: {missing_cols}"
    )

print("Dataset uploaded and validated successfully.")
print("Uploaded file:", file_name)
print("Dataset shape:", df.shape)

display(df.head())
# Out:
# Please upload your PM₂.₅ dataset CSV file.
# Required columns:
# ['date', 'pm10', 'pm2_5', 'carbon_monoxide', 'nitrogen_dioxide', 'sulphur_dioxide', 'ozone', 'aerosol_optical_depth', 'dust', 'uv_index']
#      <input type="file" id="files-d80a4e26-a7ff-47c2-af1f-514fd896bceb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d80a4e26-a7ff-47c2-af1f-514fd896bceb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# ...

# %%
# ============================================================
# CELL 4: Parse Date and Filter Date Range
# ============================================================
# User date range:
# 04-08-2022 to 18-02-2026
# Date format is day-month-year.
# ============================================================

df["date"] = pd.to_datetime(df["date"], errors="coerce", dayfirst=True)

df = df.dropna(subset=["date"])
df = df.sort_values("date").reset_index(drop=True)

start_date = pd.to_datetime("04-08-2022", dayfirst=True)
end_date = pd.to_datetime("18-02-2026", dayfirst=True)

df = df[(df["date"] >= start_date) & (df["date"] <= end_date)].copy()
df = df.sort_values("date").reset_index(drop=True)

print("Filtered date range:")
print("Start:", df["date"].min())
print("End:", df["date"].max())
print("Shape after filtering:", df.shape)

display(df.head())
display(df.tail())
# Out:
# Filtered date range:
# Start: 2022-08-04 00:00:00
# End: 2026-02-18 00:00:00
# Shape after filtering: (1295, 10)
#         date        pm10      pm2_5  carbon_monoxide  nitrogen_dioxide  \
# 0 2022-08-04   63.178947  43.594737       750.105263         52.600000
# 1 2022-08-05   63.750000  43.929167       918.541667         49.037500
# 2 2022-08-06  107.050000  73.745833      1395.875000         81.204167
# 3 2022-08-07   61.029167  42.170833       902.166667         65.804167
# 4 2022-08-08   75.850000  52.733333      1179.041667         65.000000
#
#    sulphur_dioxide       ozone  aerosol_optical_depth      dust  uv_index
# 0        60.931579   69.631579               1.243158  2.578947  0.623684
# 1        43.504167   72.208333               0.722500  3.000000  1.008333
# 2        69.608333  105.291667               0.854167  4.750000  1.731250
# 3        48.504167   64.833333               0.853333  2.500000  1.339583
# ...

# %%
# ============================================================
# CELL 5: Convert Variables to Numeric and Clean Missing Values
# ============================================================

pollutant_cols = [
    "pm10",
    "pm2_5",
    "carbon_monoxide",
    "nitrogen_dioxide",
    "sulphur_dioxide",
    "ozone",
    "aerosol_optical_depth",
    "dust",
    "uv_index"
]

for col in pollutant_cols:
    df[col] = pd.to_numeric(df[col], errors="coerce")

df[pollutant_cols] = df[pollutant_cols].replace([np.inf, -np.inf], np.nan)

print("Missing values before interpolation:")
display(df.isnull().sum())

# Ensure daily sequence.
full_dates = pd.date_range(df["date"].min(), df["date"].max(), freq="D")
df = df.set_index("date").reindex(full_dates)
df.index.name = "date"
df = df.reset_index()

# Linear interpolation is suitable for daily environmental time series.
df[pollutant_cols] = df[pollutant_cols].interpolate(method="linear")
df[pollutant_cols] = df[pollutant_cols].bfill().ffill()

print("Missing values after interpolation:")
display(df.isnull().sum())

print("Final cleaned shape:", df.shape)
display(df.head())
# Out:
# Missing values before interpolation:
# date                     0
# pm10                     0
# pm2_5                    0
# carbon_monoxide          0
# nitrogen_dioxide         0
# sulphur_dioxide          0
# ozone                    0
# aerosol_optical_depth    0
# dust                     0
# uv_index                 0
# dtype: int64
# Missing values after interpolation:
# date                     0
# pm10                     0
# pm2_5                    0
# carbon_monoxide          0
# nitrogen_dioxide         0
# sulphur_dioxide          0
# ozone                    0
# aerosol_optical_depth    0
# dust                     0
# uv_index                 0
# dtype: int64
# Final cleaned shape: (1295, 10)
#         date        pm10      pm2_5  carbon_monoxide  nitrogen_dioxide  \
# 0 2022-08-04   63.178947  43.594737       750.105263         52.600000
# 1 2022-08-05   63.750000  43.929167       918.541667         49.037500
# ...

# %%
# ============================================================
# CELL 6: Exploratory Plot of PM2.5
# ============================================================

plt.figure(figsize=(15, 5))

plt.plot(
    df["date"],
    df["pm2_5"],
    linewidth=1.2,
    label="Observed PM₂.₅"
)

plt.xlabel("Date")
plt.ylabel("PM₂.₅")
plt.title("Daily PM₂.₅ Concentration from 04-08-2022 to 18-02-2026")

plt.legend(
    loc="upper right",
    frameon=True
)

plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

display(df[pollutant_cols].describe().T)
# Out:
#                         count         mean         std        min         25%  \
# pm10                   1295.0   141.081390  103.512731   0.895833   79.089583
# pm2_5                  1295.0    73.538291   38.274817   0.620833   45.187500
# carbon_monoxide        1295.0  1002.133704  662.683056  60.333333  546.791667
# nitrogen_dioxide       1295.0    42.389743   21.651176   0.000000   26.783333
# sulphur_dioxide        1295.0    38.202676   24.046676   0.529167   22.729167
# ozone                  1295.0    85.288422   23.340610  21.458333   69.270833
# aerosol_optical_depth  1295.0     0.603134    0.300518   0.037083    0.370625
# dust                   1295.0   107.858845  197.715990   0.000000    5.541667
# uv_index               1295.0     1.283167    0.526847   0.141667    0.808333
#
#                               50%          75%          max
# pm10                   114.854167   164.350000   929.841667
# pm2_5                   63.383333    93.772917   256.733333
# ...

# %%
# ============================================================
# CELL 7: Train-Test Split for Multi-Step Forecasting
# ============================================================
# TimesFM forecasts the full test horizon from the training context.
# First 80% = training context
# Last 20% = test horizon
# ============================================================

target_col = "pm2_5"

split_index = int(len(df) * 0.80)

train_df = df.iloc[:split_index].copy()
test_df = df.iloc[split_index:].copy()

prediction_length = len(test_df)

print("Training period:")
print(train_df["date"].min(), "to", train_df["date"].max())
print("Training length:", len(train_df))

print("\nTesting period:")
print(test_df["date"].min(), "to", test_df["date"].max())
print("Testing length / prediction length:", prediction_length)

y_train = train_df[target_col].astype(float).values
y_test = test_df[target_col].astype(float).values
date_test = test_df["date"].values
# Out:
# Training period:
# 2022-08-04 00:00:00 to 2025-06-04 00:00:00
# Training length: 1036
#
# Testing period:
# 2025-06-05 00:00:00 to 2026-02-18 00:00:00
# Testing length / prediction length: 259

# %%
# ============================================================
# CELL 8: Evaluation Function and Result Containers
# ============================================================

all_results = []
all_predictions = {}

def evaluate_forecast(y_true, y_pred, model_name):
    y_true = np.asarray(y_true, dtype=float)
    y_pred = np.asarray(y_pred, dtype=float)

    n = min(len(y_true), len(y_pred))
    y_true = y_true[:n]
    y_pred = y_pred[:n]

    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    r2 = r2_score(y_true, y_pred)

    mape = np.mean(
        np.abs((y_true - y_pred) / np.maximum(np.abs(y_true), 1.0))
    ) * 100

    numerator = np.sum((y_pred - y_true) ** 2)
    denominator = np.sum(
        (np.abs(y_pred - np.mean(y_true)) + np.abs(y_true - np.mean(y_true))) ** 2
    )

    ioa = 1 - numerator / denominator if denominator != 0 else np.nan

    return {
        "Model": model_name,
        "MAE": mae,
        "RMSE": rmse,
        "MAPE (%)": mape,
        "R2": r2,
        "Index of Agreement": ioa
    }

def add_result(model_name, pred):
    pred = np.asarray(pred, dtype=float)
    pred = pred[:len(y_test)]

    all_predictions[model_name] = pred
    all_results.append(evaluate_forecast(y_test, pred, model_name))

    print(f"{model_name} completed.")
    display(pd.DataFrame(all_results).sort_values("RMSE").reset_index(drop=True))

print("Evaluation utilities ready.")
# Out:
# Evaluation utilities ready.

# %%
# ============================================================
# CELL 9: Baseline Forecasting Models
# ============================================================

# 1. Persistence forecast:
# Every future value = last observed PM2.5 in training.
persistence_pred = np.repeat(y_train[-1], prediction_length)

add_result(
    "Persistence Baseline",
    persistence_pred
)

# 2. Seasonal naive weekly forecast:
# Repeat last 7 days pattern.
last_week = y_train[-7:]

seasonal_naive_pred = np.resize(
    last_week,
    prediction_length
)

add_result(
    "Seasonal Naive Weekly",
    seasonal_naive_pred
)

# 3. Historical mean baseline:
mean_pred = np.repeat(
    np.mean(y_train),
    prediction_length
)

add_result(
    "Historical Mean Baseline",
    mean_pred
)
# Out:
# Persistence Baseline completed.
#                   Model        MAE       RMSE   MAPE (%)        R2  \
# 0  Persistence Baseline  35.224067  42.740154  60.099796 -0.066452
#
#    Index of Agreement
# 0            0.275504
# Seasonal Naive Weekly completed.
#                    Model        MAE       RMSE   MAPE (%)        R2  \
# 0   Persistence Baseline  35.224067  42.740154  60.099796 -0.066452
# 1  Seasonal Naive Weekly  36.962275  44.468264  61.892399 -0.154435
#
#    Index of Agreement
# 0            0.275504
# 1            0.289786
# Historical Mean Baseline completed.
#                       Model        MAE       RMSE   MAPE (%)        R2  \
# 0      Persistence Baseline  35.224067  42.740154  60.099796 -0.066452
# 1  Historical Mean Baseline  31.927842  42.828396  42.941425 -0.070860
# 2     Seasonal Naive Weekly  36.962275  44.468264  61.892399 -0.154435
#
#    Index of Agreement
# 0            0.275504
# 1            0.281126
# 2            0.289786

# %%
# ============================================================
# CELL 10: Prepare PM2.5 Context for TimesFM 2.5
# ============================================================
# TimesFM 2.5 receives a list of 1D tensors as past_values.
# Here, we use PM₂.₅ as a univariate forecasting series.
# ============================================================

device = "cuda" if torch.cuda.is_available() else "cpu"

pm25_context = torch.tensor(
    y_train,
    dtype=torch.float32,
    device=device
)

past_values = [
    pm25_context
]

print("TimesFM input prepared.")
print("Device:", device)
print("Context length:", len(pm25_context))
print("Prediction length:", prediction_length)
print("Number of input series:", len(past_values))
# Out:
# TimesFM input prepared.
# Device: cuda
# Context length: 1036
# Prediction length: 259
# Number of input series: 1

# %%
# ============================================================
# CELL 11: Load TimesFM 2.5 Model from Transformers
# ============================================================
# Model:
# google/timesfm-2.5-200m-transformers
#
# Class:
# TimesFm2_5ModelForPrediction
#
# If this cell fails, restart runtime after Cell 1 installation.
# ============================================================

try:
    from transformers import TimesFm2_5ModelForPrediction

    timesfm_model_name = "google/timesfm-2.5-200m-transformers"

    timesfm_model = TimesFm2_5ModelForPrediction.from_pretrained(
        timesfm_model_name
    )

    timesfm_model = timesfm_model.to(torch.float32)
    timesfm_model = timesfm_model.to(device)
    timesfm_model = timesfm_model.eval()

    print("TimesFM 2.5 model loaded successfully.")
    print("Model:", timesfm_model_name)
    print("Device:", device)

except Exception as e:
    print("TimesFM 2.5 model loading failed.")
    print("Possible reasons:")
    print("1. Runtime was not restarted after installing latest Transformers.")
    print("2. The installed Transformers version does not yet expose TimesFm2_5ModelForPrediction.")
    print("3. Colab memory is insufficient.")
    print("Error:")
    print(e)
# Out:
# config.json:   0%|          | 0.00/914 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/925M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/272 [00:00<?, ?it/s]
# TimesFM 2.5 model loaded successfully.
# Model: google/timesfm-2.5-200m-transformers
# Device: cuda

# %%
# ============================================================
# CELL 12: TimesFM 2.5 Forecasting
# ============================================================
# This cell generates point and quantile forecasts.
#
# The model call follows the official Transformers-style usage:
#
# outputs = model(
#     past_values=past_values,
#     forecast_context_len=1024
# )
#
# The output usually contains:
# outputs.mean_predictions
# outputs.full_predictions
# ============================================================

try:
    gc.collect()

    if torch.cuda.is_available():
        torch.cuda.empty_cache()
        torch.cuda.ipc_collect()

    with torch.no_grad():
        timesfm_outputs = timesfm_model(
            past_values=past_values,
            forecast_context_len=1024
        )

    print("TimesFM 2.5 forecasting completed.")

    if hasattr(timesfm_outputs, "mean_predictions"):
        print("Mean predictions shape:", timesfm_outputs.mean_predictions.shape)

    if hasattr(timesfm_outputs, "full_predictions"):
        print("Full predictions shape:", timesfm_outputs.full_predictions.shape)

except Exception as e:
    print("TimesFM 2.5 forecasting failed.")
    print("Possible reasons:")
    print("1. The forecast horizon produced by the model is shorter than your test horizon.")
    print("2. Runtime memory is insufficient.")
    print("3. Transformers API changed.")
    print("Error:")
    print(e)
# Out:
# TimesFM 2.5 forecasting completed.
# Mean predictions shape: torch.Size([1, 128])
# Full predictions shape: torch.Size([1, 128, 10])

# %%
# ============================================================
# CELL 13: Extract TimesFM 2.5 Forecast Values
# ============================================================
# This cell extracts the mean forecast as the main predicted series.
# If the model output is shorter than the test horizon, the comparison
# automatically uses the common available length.
# ============================================================

try:
    if hasattr(timesfm_outputs, "mean_predictions"):
        timesfm_pred_raw = timesfm_outputs.mean_predictions.detach().cpu().numpy()

    elif hasattr(timesfm_outputs, "full_predictions"):
        timesfm_full = timesfm_outputs.full_predictions.detach().cpu().numpy()
        timesfm_pred_raw = np.mean(timesfm_full, axis=-1)

    else:
        raise ValueError("No prediction field found in TimesFM output.")

    timesfm_pred = np.asarray(timesfm_pred_raw).flatten()

    usable_length = min(
        len(timesfm_pred),
        prediction_length
    )

    timesfm_pred = timesfm_pred[:usable_length]

    print("TimesFM forecast extracted successfully.")
    print("Raw forecast length:", len(np.asarray(timesfm_pred_raw).flatten()))
    print("Usable forecast length:", usable_length)

    add_result(
        "TimesFM 2.5 Transformers",
        timesfm_pred
    )

except Exception as e:
    print("TimesFM forecast extraction failed.")
    print("Error:")
    print(e)
# Out:
# TimesFM forecast extracted successfully.
# Raw forecast length: 128
# Usable forecast length: 128
# TimesFM 2.5 Transformers completed.
#                       Model        MAE       RMSE   MAPE (%)        R2  \
# 0  TimesFM 2.5 Transformers  17.351127  22.185171  33.348131  0.090159
# 1      Persistence Baseline  35.224067  42.740154  60.099796 -0.066452
# 2  Historical Mean Baseline  31.927842  42.828396  42.941425 -0.070860
# 3     Seasonal Naive Weekly  36.962275  44.468264  61.892399 -0.154435
#
#    Index of Agreement
# 0            0.441576
# 1            0.275504
# 2            0.281126
# 3            0.289786

# %%
# ============================================================
# CELL 14: Plot TimesFM 2.5 Forecast
# ============================================================
# This cell plots observed PM₂.₅ against TimesFM 2.5 prediction.
#
# Legend is placed inside the plot at the upper-right corner,
# following your preferred style.
# ============================================================

timesfm_predictions = {}

for model_name, prediction_values in all_predictions.items():
    try:
        if prediction_values is not None and "TimesFM" in model_name:
            timesfm_predictions[model_name] = prediction_values
    except NameError:
        pass

print("Available TimesFM models for plotting:")

if len(timesfm_predictions) == 0:
    print("No TimesFM prediction found.")
    print("Please run Cell 12 and Cell 13 successfully before running this cell.")
else:
    for model_name in timesfm_predictions.keys():
        print("-", model_name)


# ------------------------------------------------------------
# Generate one plot for each available TimesFM model
# ------------------------------------------------------------

for model_name, prediction_values in timesfm_predictions.items():

    prediction_values = np.asarray(prediction_values, dtype=float)

    n = min(
        len(date_test),
        len(y_test),
        len(prediction_values)
    )

    plt.figure(figsize=(15, 5))

    plt.plot(
        date_test[:n],
        y_test[:n],
        label="Observed PM₂.₅",
        linewidth=1.5
    )

    plt.plot(
        date_test[:n],
        prediction_values[:n],
        label=f"Predicted PM₂.₅ - {model_name}",
        linewidth=1.5
    )

    plt.xlabel("Date")
    plt.ylabel("PM₂.₅")
    plt.title(f"Observed vs Predicted PM₂.₅ using {model_name}")

    plt.legend(
        loc="upper right",
        frameon=True
    )

    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
# Out:
# Available TimesFM models for plotting:
# - TimesFM 2.5 Transformers
